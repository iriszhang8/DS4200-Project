# %%
import pandas as pd
import re

# %%
# Load the data
costco = pd.read_csv("GroceryDataset.csv")

# %%
# Check for missing values
costco.isnull().sum()
# Out:
# Sub Category              0
# Price                     3
# Discount                  0
# Rating                 1075
# Title                     0
# Currency                  5
# Feature                  18
# Product Description      42
# dtype: int64

# %%
# Drop the Currency & Rating columns
df = costco.drop(columns=["Currency", "Rating"], errors="ignore")
df.head()
# Out:
#         Sub Category     Price     Discount  \
# 0  Bakery & Desserts   $56.99   No Discount
# 1  Bakery & Desserts  $159.99   No Discount
# 2  Bakery & Desserts   $44.99   No Discount
# 3  Bakery & Desserts   $39.99   No Discount
# 4  Bakery & Desserts   $59.99   No Discount
#
#                                                Title  \
# 0  David’s Cookies Mile High Peanut Butter Cake, ...
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...
# 2  St Michel Madeleine, Classic French Sponge Cak...
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...
#
#                                              Feature  \
# 0  "10"" Peanut Butter Cake\nCertified Kosher OU-...
# 1  Spiced Carrot Cake with Cream Cheese Frosting ...
# 2  100 count\nIndividually wrapped\nMade in and I...
# 3  Butter Pecan Meltaways\n32 oz 2-Pack\nNo Prese...
# 4  "10" Four Layer Chocolate Cake\nCertified Kosh...
#
#                                  Product Description
# 0  A cake the dessert epicure will die for!Our To...
# 1  Due to the perishable nature of this item, ord...
# 2  Moist and buttery sponge cakes with the tradit...
# 3  These delectable butter pecan meltaways are th...
# 4  A cake the dessert epicure will die for!To the...

# %%
# Check for null values
df.isnull().sum()
# Out:
# Sub Category            0
# Price                   3
# Discount                0
# Title                   0
# Feature                18
# Product Description    42
# dtype: int64

# %%
# Drop null values
df = df.dropna().reset_index(drop=True)

# %%
# Remove the $ symbol from the Price column and convert to float
df["Price"] = df["Price"].astype(str).apply(lambda x: re.findall(r"\d+\.\d+|\d+", x)[0] if re.findall(r"\d+\.\d+|\d+", x) else None)
df["Price"] = df["Price"].astype(float)

# %%
# Convert "Discount" column -> 0 for No Discount, 1 for any discount
df["Discount"] = df["Discount"].apply(lambda x: 0 if x == "No Discount" else 1)

# %%
df.head()
# Out:
#         Sub Category   Price  Discount  \
# 0  Bakery & Desserts   56.99         0
# 1  Bakery & Desserts  159.99         0
# 2  Bakery & Desserts   44.99         0
# 3  Bakery & Desserts   39.99         0
# 4  Bakery & Desserts   59.99         0
#
#                                                Title  \
# 0  David’s Cookies Mile High Peanut Butter Cake, ...
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...
# 2  St Michel Madeleine, Classic French Sponge Cak...
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...
#
#                                              Feature  \
# 0  "10"" Peanut Butter Cake\nCertified Kosher OU-...
# 1  Spiced Carrot Cake with Cream Cheese Frosting ...
# 2  100 count\nIndividually wrapped\nMade in and I...
# 3  Butter Pecan Meltaways\n32 oz 2-Pack\nNo Prese...
# 4  "10" Four Layer Chocolate Cake\nCertified Kosh...
#
#                                  Product Description
# 0  A cake the dessert epicure will die for!Our To...
# 1  Due to the perishable nature of this item, ord...
# 2  Moist and buttery sponge cakes with the tradit...
# 3  These delectable butter pecan meltaways are th...
# 4  A cake the dessert epicure will die for!To the...

# %%
# Export df to CSV
df.to_csv("cleaned_costco_data.csv", index=False)

# %%
# New df with reviews
df_reviews = costco.drop(columns=["Currency"], errors="ignore")
df_reviews.head()
# Out:
#         Sub Category     Price     Discount  \
# 0  Bakery & Desserts   $56.99   No Discount
# 1  Bakery & Desserts  $159.99   No Discount
# 2  Bakery & Desserts   $44.99   No Discount
# 3  Bakery & Desserts   $39.99   No Discount
# 4  Bakery & Desserts   $59.99   No Discount
#
#                                             Rating  \
# 0   Rated 4.3 out of 5 stars based on 265 reviews.
# 1       Rated 5 out of 5 stars based on 1 reviews.
# 2   Rated 4.1 out of 5 stars based on 441 reviews.
# 3  Rated 4.7 out of 5 stars based on 9459 reviews.
# 4   Rated 4.5 out of 5 stars based on 758 reviews.
#
#                                                Title  \
# 0  David’s Cookies Mile High Peanut Butter Cake, ...
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...
# 2  St Michel Madeleine, Classic French Sponge Cak...
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...
#
#                                              Feature  \
# 0  "10"" Peanut Butter Cake\nCertified Kosher OU-...
# 1  Spiced Carrot Cake with Cream Cheese Frosting ...
# 2  100 count\nIndividually wrapped\nMade in and I...
# 3  Butter Pecan Meltaways\n32 oz 2-Pack\nNo Prese...
# 4  "10" Four Layer Chocolate Cake\nCertified Kosh...
#
#                                  Product Description
# 0  A cake the dessert epicure will die for!Our To...
# 1  Due to the perishable nature of this item, ord...
# 2  Moist and buttery sponge cakes with the tradit...
# 3  These delectable butter pecan meltaways are th...
# 4  A cake the dessert epicure will die for!To the...

# %%
# Check for null values
df_reviews.isnull().sum()
# Out:
# Sub Category              0
# Price                     3
# Discount                  0
# Rating                 1075
# Title                     0
# Feature                  18
# Product Description      42
# dtype: int64

# %%
# Drop null values
df_reviews = df_reviews.dropna().reset_index(drop=True)

# %%
# Get just the rating value from the Rating column
df_reviews["Rating"] = df_reviews["Rating"].str.extract(r'Rated ([\d\.]+) out of 5')[0].astype(float)

# %%
# Remove the $ symbol from the Price column and convert to float
df_reviews["Price"] = df_reviews["Price"].astype(str).apply(lambda x: re.findall(r"\d+\.\d+|\d+", x)[0] if re.findall(r"\d+\.\d+|\d+", x) else None)
df_reviews["Price"] = df_reviews["Price"].astype(float)

# %%
# Convert "Discount" column -> 0 for No Discount, 1 for any discount
df_reviews["Discount"] = df_reviews["Discount"].apply(lambda x: 0 if x == "No Discount" else 1)

# %%
df_reviews.head()
# Out:
#         Sub Category   Price  Discount  Rating  \
# 0  Bakery & Desserts   56.99         0     4.3
# 1  Bakery & Desserts  159.99         0     5.0
# 2  Bakery & Desserts   44.99         0     4.1
# 3  Bakery & Desserts   39.99         0     4.7
# 4  Bakery & Desserts   59.99         0     4.5
#
#                                                Title  \
# 0  David’s Cookies Mile High Peanut Butter Cake, ...
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...
# 2  St Michel Madeleine, Classic French Sponge Cak...
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...
#
#                                              Feature  \
# 0  "10"" Peanut Butter Cake\nCertified Kosher OU-...
# 1  Spiced Carrot Cake with Cream Cheese Frosting ...
# 2  100 count\nIndividually wrapped\nMade in and I...
# 3  Butter Pecan Meltaways\n32 oz 2-Pack\nNo Prese...
# 4  "10" Four Layer Chocolate Cake\nCertified Kosh...
#
#                                  Product Description
# 0  A cake the dessert epicure will die for!Our To...
# 1  Due to the perishable nature of this item, ord...
# 2  Moist and buttery sponge cakes with the tradit...
# 3  These delectable butter pecan meltaways are th...
# 4  A cake the dessert epicure will die for!To the...
